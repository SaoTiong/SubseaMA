# %%
import cv2

video_path =  '/run/user/1000/gvfs/smb-share:server=unas-pro.local,share=dwe_nas/Recordings/2025/09-24-scripps/AVI/recording_2025-09-24_09-53-09_cam1-fixed.avi' 
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file: {video_path}")
else:
    frame_count = 0
    while True:
        # cap.read() returns True if a frame was read successfully
        success, frame = cap.read()
        if not success:
            # If no frame is returned, we've reached the end
            break
        frame_count += 1

    print(f"Total frames (manually counted): {frame_count}")
    cap.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 frame_count = 0
#      10 while True:
#      11     # cap.read() returns True if a frame was read successfully
# ---> 12     success, frame = cap.read()
#      13     if not success:
#      14         # If no frame is returned, we've reached the end
#      15         break
#
# KeyboardInterrupt:

# %%
import cv2
import os

# --- 1. Configuration ---
video_path = '/run/user/1000/gvfs/smb-share:server=unas-pro.local,share=dwe_nas/Recordings/2025/09-24-scripps/AVI/recording_2025-09-24_09-53-09_cam1-fixed.avi' 
output_folder = '/home/tong/recordings/scripps918_1' 
 # A folder to save the images
frames_to_save = 6000

# --- 2. Setup ---
# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video opened successfully
if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()

print(f"Saving the first {frames_to_save} frames to '{output_folder}'...")

# --- 3. Loop and Save Frames ---
for frame_num in range(frames_to_save):
    # Read one frame from the video
    success, frame = cap.read()

    # If 'success' is False, it means we reached the end of the video
    if not success:
        print(f"Video ended before reaching {frames_to_save} frames. Saved {frame_num} frames.")
        break

    # Construct the output filename with zero-padding (e.g., frame_0001.jpg)
    filename = f"{output_folder}/frame_{frame_num:04d}.jpg"

    # Save the current frame as a JPEG image
    cv2.imwrite(filename, frame)

    # Optional: Print progress
    if (frame_num + 1) % 100 == 0:
        print(f"Saved frame {frame_num + 1} of {frames_to_save}")


# --- 4. Cleanup ---
cap.release()
print("✅ Done.")
# Out:
# Saving the first 6000 frames to '/home/tong/recordings/scripps918_1'...
# Saved frame 100 of 6000
# Saved frame 200 of 6000
# Saved frame 300 of 6000
# Saved frame 400 of 6000
# Saved frame 500 of 6000
# Saved frame 600 of 6000
# Saved frame 700 of 6000
# Saved frame 800 of 6000
# Saved frame 900 of 6000
# Saved frame 1000 of 6000
# Saved frame 1100 of 6000
# Saved frame 1200 of 6000
# Saved frame 1300 of 6000
# Saved frame 1400 of 6000
# Saved frame 1500 of 6000
# Saved frame 1600 of 6000
# Saved frame 1700 of 6000
# Saved frame 1800 of 6000
# Saved frame 1900 of 6000
# Saved frame 2000 of 6000
# Saved frame 2100 of 6000
# Saved frame 2200 of 6000
# Saved frame 2300 of 6000
# Saved frame 2400 of 6000
# Saved frame 2500 of 6000
# Saved frame 2600 of 6000
# Saved frame 2700 of 6000
# Saved frame 2800 of 6000
# Saved frame 2900 of 6000
# Saved frame 3000 of 6000
# Saved frame 3100 of 6000
# Saved frame 3200 of 6000
# Saved frame 3300 of 6000
# Saved frame 3400 of 6000
# ...

# %%
import cv2
import os
import collections

# --- 1. Configuration ---
video_path = '/run/user/1000/gvfs/smb-share:server=unas-pro.local,share=dwe_nas/Recordings/2025/08-28-more-rocks/AVI/More Rocks_cam2.avi'
output_folder = '/home/tong/recordings/moreRocks2_2' # New folder for clarity
frames_to_save = 1000

# --- 2. Setup ---
os.makedirs(output_folder, exist_ok=True)
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()

# Use a deque as a fixed-size buffer to hold the last N frames
frame_buffer = collections.deque(maxlen=frames_to_save)

print(f"Reading video to find the last {frames_to_save} frames. This may take a moment...")

# --- 3. Read all frames into the rolling buffer ---
while True:
    success, frame = cap.read()
    if not success:
        # End of the video
        break
    
    # Add the latest frame; the deque automatically removes the oldest if full
    frame_buffer.append(frame)

print(f"✅ Video read complete. Buffer contains {len(frame_buffer)} frames.")
print(f"Now saving frames to '{output_folder}'...")

# --- 4. Save the frames that are now in the buffer ---
for i, frame in enumerate(frame_buffer):
    # Construct the output filename
    filename = f"{output_folder}/frame_{i:04d}.jpg"
    
    # Save the frame
    cv2.imwrite(filename, frame)
    
    if (i + 1) % 100 == 0:
        print(f"Saved frame {i + 1} of {len(frame_buffer)}")

# --- 5. Cleanup ---
cap.release()
print("✅ Done.")
# Out:
# Reading video to find the last 1000 frames. This may take a moment...
# ✅ Video read complete. Buffer contains 1000 frames.
# Now saving frames to '/home/tong/recordings/moreRocks2_2'...
# Saved frame 100 of 1000
# Saved frame 200 of 1000
# Saved frame 300 of 1000
# Saved frame 400 of 1000
# Saved frame 500 of 1000
# Saved frame 600 of 1000
# Saved frame 700 of 1000
# Saved frame 800 of 1000
# Saved frame 900 of 1000
# Saved frame 1000 of 1000
# ✅ Done.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import tkinter as tk
from tkinter import messagebox, filedialog
import os

# --- 1. Configuration ---
# Your video file path
VIDEO_PATH = '/run/user/1000/gvfs/smb-share:server=unas-pro.local,share=dwe_nas/Recordings/2025/09-24-scripps/AVI/recording_2025-09-24_09-53-09_cam1-fixed.avi'
WINDOW_NAME = 'Interactive Frame Saver'
SEEK_AMOUNT = 150 # Number of frames to jump forward or backward

# --- 2. Main Application Logic ---
def run_player():
    """
    Initializes and runs the main video player loop.
    """
    # --- Initialization ---
    root = tk.Tk()
    root.withdraw() 

    cap = cv2.VideoCapture(VIDEO_PATH)
    if not cap.isOpened():
        messagebox.showerror("Error", f"Could not open video file:\n{VIDEO_PATH}")
        return
    
    # State variables
    is_paused = False
    is_saving_frames = False
    save_folder = ""
    saved_frame_count = 0

    print("--- Controls ---")
    print("  r : Start saving frames")
    print("  s : Stop saving frames")
    print("  d : Fast-forward")
    print("  a : Rewind")
    print("  q : Quit the player")
    print("----------------")

    # --- Main Loop ---
    while True:
        if not is_paused:
            success, frame = cap.read()
            if not success:
                print("End of video reached.")
                break
        
        display_frame = frame.copy()
        status_text = ""
        status_color = (0, 0, 0)
        if is_saving_frames:
            status_text = f"● SAVING FRAMES ({saved_frame_count})"
            status_color = (0, 0, 255) # Red
        elif is_paused:
            status_text = "|| PAUSED"
            status_color = (255, 165, 0) # Orange
        
        if status_text:
             cv2.putText(display_frame, status_text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 4, cv2.LINE_AA)
             cv2.putText(display_frame, status_text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, status_color, 2, cv2.LINE_AA)

        cv2.imshow(WINDOW_NAME, display_frame)

        # Handle frame saving if active
        if is_saving_frames and not is_paused:
            filename = os.path.join(save_folder, f"frame_{saved_frame_count:06d}.jpg")
            cv2.imwrite(filename, frame)
            saved_frame_count += 1

        key = cv2.waitKey(30) & 0xFF

        if key == ord('q'):
            break

        # Start Saving Frames
        elif key == ord('r'):
            if is_saving_frames:
                messagebox.showwarning("Frame Saver", "Already saving frames!")
                continue

            is_paused = True
            if messagebox.askyesno("Frame Saver", "Start saving frames?"):
                folder_path = filedialog.askdirectory(title="Select a folder to save frames")
                
                if folder_path:
                    save_folder = folder_path
                    is_saving_frames = True
                    saved_frame_count = 0
                    print(f"Saving frames to: {save_folder}")
                else:
                    print("Frame saving cancelled by user.")
            
            is_paused = False

        # Stop Saving Frames
        elif key == ord('s'):
            if not is_saving_frames:
                messagebox.showinfo("Frame Saver", "Not currently saving any frames.")
                continue

            is_paused = True
            if messagebox.askyesno("Frame Saver", f"Stop saving frames? ({saved_frame_count} frames saved)"):
                is_saving_frames = False
                print(f"Stopped saving. Total frames saved in this session: {saved_frame_count}")
            
            is_paused = False
        
        # Rewind
        elif key == ord('a'):
            if not is_saving_frames:
                current_frame_pos = cap.get(cv2.CAP_PROP_POS_FRAMES)
                new_pos = max(0, current_frame_pos - SEEK_AMOUNT)
                cap.set(cv2.CAP_PROP_POS_FRAMES, new_pos)
                print(f"Rewound to frame ~{int(new_pos)}")

        # Fast-forward
        elif key == ord('d'):
            if not is_saving_frames:
                current_frame_pos = cap.get(cv2.CAP_PROP_POS_FRAMES)
                cap.set(cv2.CAP_PROP_POS_FRAMES, current_frame_pos + SEEK_AMOUNT)
                print(f"Fast-forwarded to frame ~{int(current_frame_pos + SEEK_AMOUNT)}")

    # --- Cleanup ---
    print("Exiting player.")
    cap.release()
    cv2.destroyAllWindows()

if __name__ == '__main__':
    run_player()
# Out:
# --- Controls ---
#   r : Start saving frames
#   s : Stop saving frames
#   d : Fast-forward
#   a : Rewind
#   q : Quit the player
# ----------------
# Fast-forwarded to frame ~279
# Fast-forwarded to frame ~431
# Fast-forwarded to frame ~584
# Fast-forwarded to frame ~737
# Fast-forwarded to frame ~888
# Fast-forwarded to frame ~1040
# Fast-forwarded to frame ~1191
# Fast-forwarded to frame ~1343
# Fast-forwarded to frame ~1496
# Fast-forwarded to frame ~1648
# Fast-forwarded to frame ~1800
# Fast-forwarded to frame ~1953
# Fast-forwarded to frame ~2105
# Fast-forwarded to frame ~2258
# Fast-forwarded to frame ~2411
# Fast-forwarded to frame ~2564
# Fast-forwarded to frame ~2716
# Fast-forwarded to frame ~2869
# Fast-forwarded to frame ~3021
# Fast-forwarded to frame ~3174
# Fast-forwarded to frame ~3326
# Fast-forwarded to frame ~3479
# Fast-forwarded to frame ~3635
# Fast-forwarded to frame ~3787
# Fast-forwarded to frame ~3939
# Fast-forwarded to frame ~4093
# ...
